# %%
from tsapix.envbase import *

# %%
from tsapix.spider.sina_keyword_screening import *

# %%
keyword='特朗普'
_resdict = normal_task_process(
    keyword=keyword, record_target=10, start_page=1, time_limit='2014-03-19 18:38:45')
pd.DataFrame(_resdict).sort_values('id')
# Out:
# 2025-09-15 18:16:33
# @ 2 2025-09-15 17:59:54 News Bag Length:  0 / 10
# 2025-09-15 18:16:43
# @ 3 2025-09-15 17:48:57 News Bag Length:  0 / 10
# 2025-09-15 18:16:53
# @ 4 2025-09-15 17:39:29 News Bag Length:  1 / 10
# 2025-09-15 18:17:03
# @ 5 2025-09-15 17:29:14 News Bag Length:  2 / 10
# 2025-09-15 18:17:13
# @ 6 2025-09-15 17:18:23 News Bag Length:  3 / 10
# 2025-09-15 18:17:24
# @ 7 2025-09-15 17:09:17 News Bag Length:  6 / 10
# 2025-09-15 18:17:34
# @ 8 2025-09-15 16:57:57 News Bag Length:  6 / 10
# 2025-09-15 18:17:44
# @ 9 2025-09-15 16:50:49 News Bag Length:  6 / 10
# 2025-09-15 18:17:54
# @ 10 2025-09-15 16:43:49 News Bag Length:  6 / 10
# 2025-09-15 18:18:04
# @ 11 2025-09-15 16:32:39 News Bag Length:  6 / 10
# 2025-09-15 18:18:15
# @ 12 2025-09-15 16:26:49 News Bag Length:  6 / 10
# 2025-09-15 18:18:25
# @ 13 2025-09-15 16:21:11 News Bag Length:  6 / 10
# 2025-09-15 18:18:35
# @ 14 2025-09-15 16:08:50 News Bag Length:  6 / 10
# 2025-09-15 18:18:45
# ...

# %%
keyword=keyword
for i in range(len(_resdict['txt'])):
    _content = _resdict['txt'][i]
    coloured_ctt = _content.replace(keyword, Colour.RED + keyword + Colour.END)
    print(_resdict['time'][i], coloured_ctt)
    print()
# Out:
# 2025-09-15 17:47:56 克里姆林宫：显然，北约在俄乌冲突中是事实上的参与者。乌克兰方面没有灵活性。（关于被冻结的俄罗斯资产）没收这些资产将损害金融体系。（谈及美国总统特朗普表示耐心正在耗尽）我们已经听到这些言论。俄罗斯仍准备通过外交途径解决乌克兰危机。
#
# 2025-09-15 17:38:10 美国驻叙利亚特使 ：我代表特朗普总统和鲁比奥国务卿表达了对卡塔尔及其首相的支持。
#
# 2025-09-15 17:18:17 【特朗普过去24小时都忙了什么？（2025-09-15）】
# 1. 凌晨将签署备忘录——特朗普将于美东时间周一下午 （北京时间次日凌晨）4 点签署总统备忘录。
# 2. 愿意对俄罗斯实施制裁——美国总统特朗普：我愿意对俄罗斯实施制裁，而欧洲必须以与美国相称的方式采取行动。
# 3. 预计美联储本周将“大幅降息”——美联储本周召开重要会议之前，特朗普周日在返回华盛顿途中对记者说：“我想会有大幅下调，现在降息时机完美。”
# 4. 加快与英国共建核电站速度——英国政府表示，美国和英国将在美国总统特朗普本周访问英国期间签署一项协议，加快两国企业建设核电站的速度。
# 5. 新美国证交会官员废除激进执法——特朗普今年任命的美国证交会主席阿特金斯承诺，在对企业“破门而入”进行激进执法之前，将向企业发出技术违规通知。
# 6. 指责华盛顿市长助长犯罪风险——特朗普称，华盛顿市长穆丽尔·鲍泽近日通知联邦政府，大都会警察局将终止与移民及海关执法局（ICE）在驱逐危险非法移民方面的合作。我郑重承诺：必要时我将宣布国家紧急状态并启动联邦接管程序！
# 7. 试图挽留外国工人——特朗普称，希望外国公司能把专业人才带来，让他们教导和培训我们的员工，学会如何制造这些独特而复杂的产品。不想因为过度限制而吓跑或打击来自外国的对美投资。
#
# 2025-09-15 17:18:17 【特朗普过去24小时都忙了什么？（2025-09-15）】
# 1. 凌晨将签署备忘录——特朗普将于美东时间周一下午 （北京时间次日凌晨）4 点签署总统备忘录。
# 2. 愿意对俄罗斯实施制裁——美国总统特朗普：我愿意对俄罗斯实施制裁，而欧洲必须以与美国相称的方式采取行动。
# ...
